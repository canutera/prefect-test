# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import subprocess, pyautogui
def get_borders_list():
    driver = webdriver.Chrome()

    driver.get("https://en.wikipedia.org/wiki/List_of_countries_and_territories_by_number_of_land_borders")

    title = driver.title
    assert "List of countries and territories by number of land borders" in title

    driver.implicitly_wait(0.5)
    df = pd.read_html(driver.page_source)[0]
    driver.quit()
    return df

import pygetwindow, os
from time import sleep

def write_to_notepad(df:pd.DataFrame):
    
    os.startfile(r"C:\WINDOWS\system32\notepad.exe")
    sleep(1)
    window = pygetwindow.getWindowsWithTitle('Notepad')[-1]
    window.activate()
    print('typing...')
    pyautogui.typewrite(df.head(3).to_string())
    sleep(5)

def delete_if_exists(file:str=r"C:\Users\gabri\OneDrive\Documents\test.txt"):
    if os.path.isfile(file):
        os.remove(file)
        return 'File Deleted!' 
    return 'File did not exist...'

def save_notepad():
    window = pygetwindow.getWindowsWithTitle('Notepad')[-1]
    window.maximize()
    window.activate()
    pyautogui.moveTo(window.left +25,window.top +40)
    pyautogui.click()
    pyautogui.moveTo(window.left +25,window.top +125)
    pyautogui.click()
    pyautogui.typewrite('test.txt')
    sleep(0.5)
    pyautogui.press('enter') 
    sleep(0.5)
    window.close()
    sleep(1)
df = get_borders_list()
write_to_notepad(df)
delete_if_exists()
save_notepad()
pd.read_fwf(r"C:\Users\gabri\OneDrive\Documents\test.txt")
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_12112\1116833236.py:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(driver.page_source)[0]

# %%
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_12112\1116833236.py:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(driver.page_source)[0]
# typing...
#    Unnamed: 0  showCountry  or territory  Total  length  of  land borders  \
# 0         NaN  showCountry  or territory    NaN     NaN NaN   NaN   km[b]
# 1         0.0          NaN   Afghanistan    NaN     NaN NaN   NaN  5529.0
# 2         1.0          NaN       Albania    NaN     NaN NaN   NaN   720.0
# 3         2.0          NaN       Algeria    NaN     NaN NaN   NaN  6470.0
#
#   Unnamed: 8  No.  ...  distinct land.1 borders.1 No..1 of.2 distinct.1  \
# 0         mi  No.  ...  distinct   land   borders   No.   of   distinct
# 1       3436  NaN  ...       NaN    NaN         6   NaN  NaN        NaN
# 2        450  NaN  ...       NaN    NaN         4   NaN  NaN        NaN
# 3       4020  NaN  ...       NaN    NaN         7   NaN  NaN        NaN
#
#   land.2  neighbours              showLand border neighbours and border  \
# 0   land  neighbours              showLand border neighbours and border
# 1    NaN           6  People's Republic of China: 76km (47mi) Iran: ...
# 2    NaN           4  Greece: 282km (175mi) Kosovo:[c] 112km (70mi) ...
# 3    NaN           7  Libya: 982km (610mi) Mali: 1,376km (855mi) Mau...
#
#   length.1
# 0   length
# 1      NaN
# 2      NaN
# 3      NaN
#
# [4 rows x 21 columns]

# %%
df
# Out:
#     showCountry or territory Total length of land borders        \
#     showCountry or territory                        km[b]    mi
# 0                Afghanistan                       5529.0  3436
# 1                    Albania                        720.0   450
# 2                    Algeria                       6470.0  4020
# 3                    Andorra                        120.0    75
# 4                     Angola                       5198.0  3230
# ..                       ...                          ...   ...
# 200                  Vietnam                       4639.0  2883
# 201        Western Sahara[d]                       2046.0  1271
# 202                    Yemen                       1746.0  1085
# 203                   Zambia                       5667.0  3521
# 204                 Zimbabwe                       3066.0  1905
#
#     No. of distinct land borders No. of distinct land neighbours  \
#     No. of distinct land borders No. of distinct land neighbours
# 0                              6                               6
# 1                              4                               4
# 2                              7                               7
# 3                              2                               2
# 4                              5                               4
# ..                           ...                             ...
# 200                            3                               3
# 201                            3                               3
# 202                            2                               2
# 203                            8                               8
# 204                            4                               4
#
#           showLand border neighbours and border length
#           showLand border neighbours and border length
# 0    People's Republic of China: 76 km (47 mi)  Ira...
# 1    Greece: 282 km (175 mi)  Kosovo:[c] 112 km (70...
# 2    Libya: 982 km (610 mi)  Mali: 1,376 km (855 mi...
# 3    France: 56.6 km (35.2 mi)  Spain: 63.7 km (39....
# 4    Democratic Republic of the Congo (2): 2,511 km...
# ..                                                 ...
# 200  Cambodia: 1,228 km (763 mi)  People's Republic...
# 201  Algeria: 42 km (26 mi)  Mauritania: 1,561 km (...
# 202  Oman: 288 km (179 mi)  Saudi Arabia: 1,458 km ...
# 203  Angola: 1,110 km (690 mi)  Botswana: 0.15 km (...
# 204  Botswana: 813 km (505 mi)  Mozambique: 1,231 k...
#
# [205 rows x 6 columns]
